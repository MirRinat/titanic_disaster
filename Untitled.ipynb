# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
import seaborn as sns
from sklearn.model_selection import RandomizedSearchCV
from sklearn import metrics
from sklearn.metrics import accuracy_score
from sklearn.metrics import roc_auc_score

# %% [markdown]
# # Чтение и очистка данных

# %%
data_train = pd.read_csv('data/train.csv')

# %%
data_train
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
y = data_train.Survived

# %%
x = data_train.drop(['Survived'], axis = 1)

# %%
data_train.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
data_train.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
data_train['Age'].fillna(data_train.Age.mean(), inplace=True)
data_train['Sex'].replace('female',0,inplace=True)
data_train['Sex'].replace('male',1,inplace=True)
data_train.drop(['Ticket'], axis = 1, inplace=True)
data_train.drop(['Name'], axis = 1, inplace=True)
data_train.drop(['PassengerId'], axis = 1, inplace=True)

# %%
data_train['Embarked'].value_counts()
# Out:
# S    644
# C    168
# Q     77
# Name: Embarked, dtype: int64

# %%
data_train['Embarked'].fillna(value="C",inplace=True)

# %%
data_train.Cabin.value_counts()
# Out:
# G6             4
# B96 B98        4
# C23 C25 C27    4
# C22 C26        3
# D              3
#               ..
# E31            1
# D28            1
# C85            1
# D10 D12        1
# D56            1
# Name: Cabin, Length: 147, dtype: int64

# %%
def data_cabin(data_train):
    data_train['Cabin'].fillna('Missing',inplace=True)
    data_train['Cabin'] = data_train['Cabin'].apply(lambda x: x[0])
    return data_train

# %%
data_train = data_cabin(data_train)
data_train.Cabin.value_counts()
# Out:
# M    687
# C     59
# B     47
# D     33
# E     32
# A     15
# F     13
# G      4
# T      1
# Name: Cabin, dtype: int64

# %%
data_train.describe()
# Out:
#          Survived      Pclass         Sex         Age       SibSp       Parch  \
# count  891.000000  891.000000  891.000000  891.000000  891.000000  891.000000
# mean     0.383838    2.308642    0.647587   29.699118    0.523008    0.381594
# std      0.486592    0.836071    0.477990   13.002015    1.102743    0.806057
# min      0.000000    1.000000    0.000000    0.420000    0.000000    0.000000
# 25%      0.000000    2.000000    0.000000   22.000000    0.000000    0.000000
# 50%      0.000000    3.000000    1.000000   29.699118    0.000000    0.000000
# 75%      1.000000    3.000000    1.000000   35.000000    1.000000    0.000000
# max      1.000000    3.000000    1.000000   80.000000    8.000000    6.000000
#
#              Fare
# count  891.000000
# mean    32.204208
# std     49.693429
# min      0.000000
# 25%      7.910400
# 50%     14.454200
# 75%     31.000000
# max    512.329200

# %%
data_train.isnull().sum()
# Out:
# Survived    0
# Pclass      0
# Sex         0
# Age         0
# SibSp       0
# Parch       0
# Fare        0
# Cabin       0
# Embarked    0
# dtype: int64

# %%
data_train.head()
# Out:
#    Survived  Pclass  Sex   Age  SibSp  Parch     Fare Cabin Embarked
# 0         0       3    1  22.0      1      0   7.2500     M        S
# 1         1       1    0  38.0      1      0  71.2833     C        C
# 2         1       3    0  26.0      0      0   7.9250     M        S
# 3         1       1    0  35.0      1      0  53.1000     C        S
# 4         0       3    1  35.0      0      0   8.0500     M        S

# %%
data_train = pd.get_dummies(data_train,drop_first=True)
data_train
# Out:
#      Survived  Pclass  Sex        Age  SibSp  Parch     Fare  Cabin_B  \
# 0           0       3    1  22.000000      1      0   7.2500        0
# 1           1       1    0  38.000000      1      0  71.2833        0
# 2           1       3    0  26.000000      0      0   7.9250        0
# 3           1       1    0  35.000000      1      0  53.1000        0
# 4           0       3    1  35.000000      0      0   8.0500        0
# ..        ...     ...  ...        ...    ...    ...      ...      ...
# 886         0       2    1  27.000000      0      0  13.0000        0
# 887         1       1    0  19.000000      0      0  30.0000        1
# 888         0       3    0  29.699118      1      2  23.4500        0
# 889         1       1    1  26.000000      0      0  30.0000        0
# 890         0       3    1  32.000000      0      0   7.7500        0
#
#      Cabin_C  Cabin_D  Cabin_E  Cabin_F  Cabin_G  Cabin_M  Cabin_T  \
# ...

# %%
def clear_data(data_train):
    data_train['Age'].fillna(data_train.Age.mean(), inplace=True)
    data_train['Sex'].replace('female',0,inplace=True)
    data_train['Sex'].replace('male',1,inplace=True)
    data_train.drop(['Ticket'], axis = 1, inplace=True)
    data_train.drop(['Name'], axis = 1, inplace=True)
    data_train.drop(['PassengerId'], axis = 1, inplace=True)
    data_train['Embarked'].fillna(value="C",inplace=True)
    data_train = data_cabin(data_train)
    data_train = pd.get_dummies(data_train,drop_first=True)
    return data_train

# %% [markdown]
# Проверка не кореллируют ли данные

# %%
correlation = data_train.corr()

# %%
correlation
# Out:
#             Survived    Pclass       Sex       Age     SibSp     Parch  \
# Survived    1.000000 -0.338481 -0.543351 -0.069809 -0.035322  0.081629
# Pclass     -0.338481  1.000000  0.131900 -0.331339  0.083081  0.018443
# Sex        -0.543351  0.131900  1.000000  0.084153 -0.114631 -0.245489
# Age        -0.069809 -0.331339  0.084153  1.000000 -0.232625 -0.179191
# SibSp      -0.035322  0.083081 -0.114631 -0.232625  1.000000  0.414838
# Parch       0.081629  0.018443 -0.245489 -0.179191  0.414838  1.000000
# Fare        0.257307 -0.549500 -0.182333  0.091566  0.159651  0.216225
# Cabin_B     0.175095 -0.369572 -0.109689  0.091394 -0.034538  0.056498
# Cabin_C     0.114652 -0.417048 -0.058649  0.113149  0.029251  0.030736
# Cabin_D     0.150716 -0.278690 -0.079248  0.132319 -0.017575 -0.019125
# Cabin_E     0.145321 -0.230091 -0.047003  0.117211 -0.036865 -0.016554
# Cabin_F     0.057935  0.011063 -0.008202 -0.077209  0.001706  0.023694
# ...

# %%
triangle = correlation.abs().where(np.tril(np.ones(correlation.shape), k=-1).astype(np.bool))

# %%
triangle.stack().sort_values(ascending=False)[:20]
# Out:
# Cabin_M     Pclass        0.725541
# Fare        Pclass        0.549500
# Sex         Survived      0.543351
# Embarked_S  Embarked_Q    0.496624
# Cabin_M     Cabin_C       0.488683
#             Fare          0.482075
#             Cabin_B       0.433053
# Cabin_C     Pclass        0.417048
# Parch       SibSp         0.414838
# Cabin_B     Fare          0.386297
#             Pclass        0.369572
# Cabin_C     Fare          0.364318
# Cabin_M     Cabin_D       0.359896
#             Cabin_E       0.354194
# Pclass      Survived      0.338481
# Age         Pclass        0.331339
# Cabin_M     Survived      0.316912
# Cabin_D     Pclass        0.278690
# Fare        Survived      0.257307
# Parch       Sex           0.245489
# dtype: float64

# %% [markdown]
# Можно проверить на точность, если удалить Fare, так как он кореллирует с Pclass, или наоборот удалить Pclass
# Также можно объеденить Parch и Sibsp

# %%
data_train.corrwith(data_train['Survived']).sort_values()
# Out:
# Sex          -0.543351
# Pclass       -0.338481
# Cabin_M      -0.316912
# Embarked_S   -0.155660
# Age          -0.069809
# SibSp        -0.035322
# Cabin_T      -0.026456
# Embarked_Q    0.003650
# Cabin_G       0.016040
# Cabin_F       0.057935
# Parch         0.081629
# Cabin_C       0.114652
# Cabin_E       0.145321
# Cabin_D       0.150716
# Cabin_B       0.175095
# Fare          0.257307
# Survived      1.000000
# dtype: float64

# %%
data_train
# Out:
#      Survived  Pclass  Sex        Age  SibSp  Parch     Fare  Cabin_B  \
# 0           0       3    1  22.000000      1      0   7.2500        0
# 1           1       1    0  38.000000      1      0  71.2833        0
# 2           1       3    0  26.000000      0      0   7.9250        0
# 3           1       1    0  35.000000      1      0  53.1000        0
# 4           0       3    1  35.000000      0      0   8.0500        0
# ..        ...     ...  ...        ...    ...    ...      ...      ...
# 886         0       2    1  27.000000      0      0  13.0000        0
# 887         1       1    0  19.000000      0      0  30.0000        1
# 888         0       3    0  29.699118      1      2  23.4500        0
# 889         1       1    1  26.000000      0      0  30.0000        0
# 890         0       3    1  32.000000      0      0   7.7500        0
#
#      Cabin_C  Cabin_D  Cabin_E  Cabin_F  Cabin_G  Cabin_M  Cabin_T  \
# ...

# %%
def clear_data(data_train):
    data_train['Age'].fillna(data_train.Age.mean(), inplace=True)
    data_train['Cabin'].fillna(0,inplace=True)
    data_train['Embarked'].fillna(value = "C",inplace=True)
    data_train['Sex'].replace('female',0,inplace=True)
    data_train['Sex'].replace('male',1,inplace=True)
    data_train = data_train.drop(['PassengerId'], axis=1)
    data_train.drop(['Name'], axis = 1, inplace = True)
    return data_train

# %% [markdown]
# # Визулизация

# %%
sns.barplot(x='Pclass', y='Survived', data=data_train)

# %%
data_train[['Pclass', 'Survived']].groupby(['Pclass'], as_index=False).mean().sort_values(by='Survived', ascending=False)
# Out:
#    Pclass  Survived
# 0       1  0.629630
# 1       2  0.472826
# 2       3  0.242363

# %%
sns.barplot(x='Sex', y='Survived', data=data_train)

# %%
plt.figure(figsize=(30, 10))
sns.barplot(x='Age', y='Survived', data=data_train)

# %%
x
# Out:
#      PassengerId  Pclass                                               Name  \
# 0              1       3                            Braund, Mr. Owen Harris
# 1              2       1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2              3       3                             Heikkinen, Miss. Laina
# 3              4       1       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4              5       3                           Allen, Mr. William Henry
# ..           ...     ...                                                ...
# 886          887       2                              Montvila, Rev. Juozas
# 887          888       1                       Graham, Miss. Margaret Edith
# 888          889       3           Johnston, Miss. Catherine Helen "Carrie"
# 889          890       1                              Behr, Mr. Karl Howell
# 890          891       3                                Dooley, Mr. Patrick
#
# ...

# %%
# data_train = clear_data(x.copy())
data_train = data_train.drop(['Survived'], axis = 1)

# %%
data_train
# Out:
#      Pclass  Sex        Age  SibSp  Parch     Fare  Cabin_B  Cabin_C  Cabin_D  \
# 0         3    1  22.000000      1      0   7.2500        0        0        0
# 1         1    0  38.000000      1      0  71.2833        0        1        0
# 2         3    0  26.000000      0      0   7.9250        0        0        0
# 3         1    0  35.000000      1      0  53.1000        0        1        0
# 4         3    1  35.000000      0      0   8.0500        0        0        0
# ..      ...  ...        ...    ...    ...      ...      ...      ...      ...
# 886       2    1  27.000000      0      0  13.0000        0        0        0
# 887       1    0  19.000000      0      0  30.0000        1        0        0
# 888       3    0  29.699118      1      2  23.4500        0        0        0
# 889       1    1  26.000000      0      0  30.0000        0        1        0
# 890       3    1  32.000000      0      0   7.7500        0        0        0
#
# ...

# %% [markdown]
# # Обучение

# %%
data_train
# Out:
#      Pclass  Sex        Age  SibSp  Parch     Fare  Cabin_B  Cabin_C  Cabin_D  \
# 0         3    1  22.000000      1      0   7.2500        0        0        0
# 1         1    0  38.000000      1      0  71.2833        0        1        0
# 2         3    0  26.000000      0      0   7.9250        0        0        0
# 3         1    0  35.000000      1      0  53.1000        0        1        0
# 4         3    1  35.000000      0      0   8.0500        0        0        0
# ..      ...  ...        ...    ...    ...      ...      ...      ...      ...
# 886       2    1  27.000000      0      0  13.0000        0        0        0
# 887       1    0  19.000000      0      0  30.0000        1        0        0
# 888       3    0  29.699118      1      2  23.4500        0        0        0
# 889       1    1  26.000000      0      0  30.0000        0        1        0
# 890       3    1  32.000000      0      0   7.7500        0        0        0
#
# ...

# %%
x = data_train

# %%
x
# Out:
#      Pclass  Sex        Age  SibSp  Parch     Fare  Cabin_B  Cabin_C  Cabin_D  \
# 0         3    1  22.000000      1      0   7.2500        0        0        0
# 1         1    0  38.000000      1      0  71.2833        0        1        0
# 2         3    0  26.000000      0      0   7.9250        0        0        0
# 3         1    0  35.000000      1      0  53.1000        0        1        0
# 4         3    1  35.000000      0      0   8.0500        0        0        0
# ..      ...  ...        ...    ...    ...      ...      ...      ...      ...
# 886       2    1  27.000000      0      0  13.0000        0        0        0
# 887       1    0  19.000000      0      0  30.0000        1        0        0
# 888       3    0  29.699118      1      2  23.4500        0        0        0
# 889       1    1  26.000000      0      0  30.0000        0        1        0
# 890       3    1  32.000000      0      0   7.7500        0        0        0
#
# ...

# %%
X_train_rf, X_validation_rf, y_train_rf, y_validation_rf = train_test_split(data_train, y, train_size=0.75, random_state=42)

# %%
model = RandomForestClassifier(random_state=42)

# %%
model.fit(X_train_rf, y_train_rf)
# Out:
# RandomForestClassifier(bootstrap=True, ccp_alpha=0.0, class_weight=None,
#                        criterion='gini', max_depth=None, max_features='auto',
#                        max_leaf_nodes=None, max_samples=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, n_estimators=100,
#                        n_jobs=None, oob_score=False, random_state=42, verbose=0,
#                        warm_start=False)

# %%
answer = model.predict(X_validation_rf)

# %%
accuracy_score(y_validation_rf, answer)
# Out:
# 0.7892376681614349

# %%
for i, j in zip(data_train.columns, model.feature_importances_):
  print(i, j)
# Out:
# Pclass 0.06911196939302533
# Sex 0.25379714958572575
# Age 0.23944947697398844
# SibSp 0.047615750600646795
# Parch 0.035232307420157635
# Fare 0.24014299057527416
# Cabin_B 0.008493744548127364
# Cabin_C 0.008214277537879485
# Cabin_D 0.007557960358374814
# Cabin_E 0.011708958689343657
# Cabin_F 0.002227891562619494
# Cabin_G 0.0014819560665684083
# Cabin_M 0.03755207268287394
# Cabin_T 0.0004083088216641573
# Embarked_Q 0.010206447103365634
# Embarked_S 0.026798738080365026
